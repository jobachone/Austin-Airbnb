# %% [markdown]
# # 6.7 - Data Revisiting and Exploration for Dashboard Purposes
#
# ## Contents
#
# #### 1. Importing Libraries and Data
#
# #### 2. Deriving Summary Statistics
# - Entire homes vs Private Rooms

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
# Setting path to Achievement 6 master folder
path = r'/Users/jeremyobach/Documents/Data Analytics/CareerFoundry/Achievement 6 - Self Designed Project/Austin Airbnb Project - MASTER FOLDER'
#checking path set correctly
path
# Out:
# '/Users/jeremyobach/Documents/Data Analytics/CareerFoundry/Achievement 6 - Self Designed Project/Austin Airbnb Project - MASTER FOLDER'

# %%
# delimiting columns displayed
pd.options.display.max_columns = None

# %% [markdown]
# ### Importing DEC23 Airbnb Data for exploration

# %%
listings = pd.read_csv(os.path.join(path,'02 Data', 'Inside Airbnb', 'Dec 23 data','Austin.dec23.listings.csv'), index_col = False)

# %%
listings.shape
# Out:
# (15419, 75)

# %%
listings.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  5456  https://www.airbnb.com/rooms/5456  20231215200307   2023-12-16
# 1  5769  https://www.airbnb.com/rooms/5769  20231215200307   2023-12-16
# 2  6413  https://www.airbnb.com/rooms/6413  20231215200307   2023-12-16
# 3  6448  https://www.airbnb.com/rooms/6448  20231215200307   2023-12-16
# 4  8502  https://www.airbnb.com/rooms/8502  20231215200307   2023-12-16
#
#             source                                               name  \
# 0      city scrape  Guesthouse in Austin · ★4.84 · 1 bedroom · 2 b...
# 1  previous scrape  Home in Austin · ★4.91 · 1 bedroom · 1 bed · 1...
# 2  previous scrape  Guesthouse in Austin · ★4.97 · Studio · 1 bed ...
# 3      city scrape  Guesthouse in Austin · ★4.97 · 1 bedroom · 2 b...
# 4      city scrape  Guest suite in Austin · ★4.56 · 1 bedroom · 1 ...
#
#    description                              neighborhood_overview  \
# ...

# %% [markdown]
# #### For the version we need to analyse, we only want:
# [host_neighborhood, host_listings_count, host_total_listings_count, neighbourhood_cleansed, latitude, longitude, property_type, room_type, accommodates, bathrooms_text, beds, price, mimium_nights, number_of_reviews, first_review, last_review, calculated_host_listings_count, reviews_per_month]

# %%
vars_list = ['host_neighbourhood', 'host_listings_count', 'host_total_listings_count', 'neighbourhood_cleansed', 'latitude', 'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms_text', 'beds', 'price', 'minimum_nights', 'number_of_reviews', 'first_review', 'last_review', 'calculated_host_listings_count', 'reviews_per_month']

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Inside Airbnb', 'Dec 23 data','Austin.dec23.listings.csv'), usecols = vars_list)

# %%
df.shape

# Reduced from 75 to 18 columns
# Specifically for visualizing in Tableau, didn't need to use cleaning measures for later actions
# Out:
# (15419, 18)

# %%
df.isnull().sum()
# Out:
# host_neighbourhood                1841
# host_listings_count                  3
# host_total_listings_count            3
# neighbourhood_cleansed               0
# latitude                             0
# longitude                            0
# property_type                        0
# room_type                            0
# accommodates                         0
# bathrooms_text                      10
# beds                               141
# price                             3128
# minimum_nights                       0
# number_of_reviews                    0
# first_review                      3141
# last_review                       3141
# calculated_host_listings_count       0
# reviews_per_month                 3141
# dtype: int64

# %%
df.to_csv(os.path.join(path,'02 Data', 'Prepared Data','listings_no_drops.csv'))

# %%
listings['calculated_host_listings_count'].value_counts()
# Out:
# calculated_host_listings_count
# 1      7221
# 2      2022
# 3      1026
# 4       608
# 5       350
# 6       324
# 7       252
# 8       184
# 91      182
# 30      180
# 23      161
# 11      143
# 9       135
# 132     132
# 129     129
# 123     123
# 17      119
# 59      118
# 16      112
# 18      108
# 10      100
# 14       98
# 48       96
# 13       91
# 15       90
# 86       86
# 42       84
# 12       84
# 82       82
# 20       80
# 80       80
# 78       78
# 26       78
# 22       66
# 21       63
# 61       61
# 29       58
# 52       52
# 24       48
# 44       44
# 39       39
# 38       38
# 19       38
# 35       35
# 33       33
# 32       32
# 31       31
# 25       25
# Name: count, dtype: int64
